# %% [markdown]
# # Libraries and Functions

# %% [markdown]
# ## Import relevant libraries

# %%
import pandas as pd

# %% [markdown]
# ## Useful functions

# %%
def split_frame(df):
    """ Clean data frame by splitting it into multiple data frames.
    
        This function will find all the indicies where the column 'd%'
        contains 'd%' and then will create a list of data frames from those
        indicies.
    """
    
    # find index
    filt = df['d%'] == 'd%'
    idx = filt[filt==True].index
    
    # create frames
    df_list = []
    # start
    df_list.append(df.iloc[:idx[0]])
    # med
    for i in range(len(idx)-1):
        df_list.append(df.iloc[idx[i]+1:idx[i+1]])
    # end
    df_list.append(df.iloc[idx[-1]+1:])
    
    return df_list

# %%
def save_data(df_list, category, names):
    """ export all data frame to csv """
    
    for df, name in zip(df_list, names):
        df.to_csv('clean_data/' + category + '/' + name + '.csv', sep=',', index=False)

# %% [markdown]
# # Anelli

# %%
df = pd.read_csv('data/Anelli_1.csv')
df
# Out:
#          d%                      Anello minore inferiore  \
# 0     01-07        Anello della Prigione del Prigioniero
# 1     08-16                    Anello dei Sigilli Arcani
# 2     17-23  Anello della Conoscenza degli Incantesimi I
# 3     26-40                      Anello di Protezione +1
# 4     41-47                      Anello dell'Avida Tomba
# ..      ...                                          ...
# 111   87-90                      Anello dei Tre Desideri
# 112   91-93               Anello del Richiamo del Djinni
# 113       -                 Anello della Psiche Nascosta
# 114   94-97            Anello del Comando degli Elementi
# 115  98-100         Anello Accumula Incantesimi Maggiore
#
#                         Prezzo    Peso       Fonte Unnamed: 5  \
# 0      Anello minore inferiore  Anello      250 mo          -
# 1      Anello minore inferiore  Anello    1.000 mo          -
# 2      Anello minore inferiore  Anello    1.500 mo          -
# 3      Anello minore inferiore  Anello    2.000 mo          -
# 4      Anello minore inferiore  Anello    2.000 mo          -
# ..                         ...     ...         ...        ...
# 111  Anello maggiore superiore  Anello  120.000 mo          -
# 112  Anello maggiore superiore  Anello  125.000 mo          -
# 113  Anello maggiore superiore  Anello  160.000 mo          -
# 114  Anello maggiore superiore  Anello  200.000 mo          -
# 115  Anello maggiore superiore  Anello  200.000 mo          -
#
#                     Unnamed: 6
# 0          Guida del Giocatore
# 1          Guida del Giocatore
# 2    Guida all'Equipaggiamento
# 3             Manuale di Gioco
# 4    Guida all'Equipaggiamento
# ..                         ...
# 111           Manuale di Gioco
# 112           Manuale di Gioco
# 113          Avventure Occulte
# 114           Manuale di Gioco
# 115           Manuale di Gioco
#
# [116 rows x 7 columns]

# %%
d = {'d%':df['d%'], 'Oggetto':df['Anello minore inferiore'], 'Prezzo':df['Fonte'], 'Fonte':df['Unnamed: 6']}
clean_df = pd.DataFrame(d)
clean_df
# Out:
#          d%                                      Oggetto      Prezzo  \
# 0     01-07        Anello della Prigione del Prigioniero      250 mo
# 1     08-16                    Anello dei Sigilli Arcani    1.000 mo
# 2     17-23  Anello della Conoscenza degli Incantesimi I    1.500 mo
# 3     26-40                      Anello di Protezione +1    2.000 mo
# 4     41-47                      Anello dell'Avida Tomba    2.000 mo
# ..      ...                                          ...         ...
# 111   87-90                      Anello dei Tre Desideri  120.000 mo
# 112   91-93               Anello del Richiamo del Djinni  125.000 mo
# 113       -                 Anello della Psiche Nascosta  160.000 mo
# 114   94-97            Anello del Comando degli Elementi  200.000 mo
# 115  98-100         Anello Accumula Incantesimi Maggiore  200.000 mo
#
#                          Fonte
# 0          Guida del Giocatore
# 1          Guida del Giocatore
# 2    Guida all'Equipaggiamento
# 3             Manuale di Gioco
# 4    Guida all'Equipaggiamento
# ..                         ...
# 111           Manuale di Gioco
# 112           Manuale di Gioco
# 113          Avventure Occulte
# 114           Manuale di Gioco
# 115           Manuale di Gioco
#
# [116 rows x 4 columns]

# %%
df_list = split_frame(clean_df)

# %%
names = ['Anelli_minori_inferiori', 'Anelli_minori_superiori', 'Anelli_medi_minori', 
        'Anelli_medi_superiori', 'Anelli_maggiori_inferiori', 'Anelli_maggiori_superiori']
save_data(df_list, 'Anelli', names)

# %% [markdown]
# # Bacchette

# %%
bacchette_df = []
for i in range(10):
    bacchette_df.append(pd.read_csv('data/Bacchette_' + str(i+1) +'.csv'))

# %%
# splitting not needed

# look at [8]
bacchette_df[8].tail()
# Out:
#                                                 d%  \
# 41                                              96
# 42                                           97-98
# 43                                              99
# 44                                             100
# 45  *  PuÃ² dissolvere livelli negativi permanenti
#
#                                   Bacchetta comune  \
# 41                           Spezzare Incantamento
# 42                                 Pelle di Pietra
# 43                       Alleato Planare Inferiore
# 44                                    Ristorare  *
# 45  *  PuÃ² dissolvere livelli negativi permanenti
#
#                                             Prezzo  \
# 41                                       30.000 mo
# 42                                       33.500 mo
# 43                                       46.000 mo
# 44                                       71.000 mo
# 45  *  PuÃ² dissolvere livelli negativi permanenti
#
#                                              Fonte
# 41                                Manuale di Gioco
# 42                                Manuale di Gioco
# 43                                Manuale di Gioco
# 44                                Manuale di Gioco
# 45  *  PuÃ² dissolvere livelli negativi permanenti

# %%
# remove the last row
bacchette_df[8] = bacchette_df[8].iloc[:-1]
bacchette_df[8].tail()
# Out:
#        d%           Bacchetta comune     Prezzo             Fonte
# 40  94-95                  Ristorare  26.000 mo  Manuale di Gioco
# 41     96      Spezzare Incantamento  30.000 mo  Manuale di Gioco
# 42  97-98            Pelle di Pietra  33.500 mo  Manuale di Gioco
# 43     99  Alleato Planare Inferiore  46.000 mo  Manuale di Gioco
# 44    100               Ristorare  *  71.000 mo  Manuale di Gioco

# %%
# change object name
for df in bacchette_df:
    df.columns = ['d%', 'Oggetto', 'Prezzo', 'Fonte']

# %%
# names
names1 = ['Bacchette_comuni_lv' + str(i) for i in range(5)]
names2 = ['Bacchette_non_comuni_lv' + str(i) for i in range(5)]

# %%
# save
save_data(bacchette_df[0::2], 'Bacchette', names1)
save_data(bacchette_df[1::2], 'Bacchette', names2)

# %% [markdown]
# # Bastoni

# %%
bastoni_df = pd.read_csv('data/Bastoni_1.csv')
bastoni_df.head()
# Out:
#         d%         Bastone medio inferiore                   Prezzo     Peso  \
# 0  01â10  Bastone del Conforto Benedetto  Bastone medio inferiore  Nessuno
# 1    11-20      Bastone dell'Arcano Minore  Bastone medio inferiore  Nessuno
# 2    21-30             Bastone dei Trucchi  Bastone medio inferiore  Nessuno
# 3    31-44        Bastone dell'Esploratore  Bastone medio inferiore  Nessuno
# 4        -   Bastone della Mostrificazione  Bastone medio inferiore  Nessuno
#
#        Fonte Unnamed: 5                 Unnamed: 6
# 0   7.200 mo     2,5 kg  Guida all'Equipaggiamento
# 1   8.000 mo     2,5 kg  Guida all'Equipaggiamento
# 2   8.800 mo     1,5 kg  Guida all'Equipaggiamento
# 3   9.600 mo       2 kg  Guida all'Equipaggiamento
# 4  12.000 mo       2 kg          Guida alle Classi

# %%
d = {'d%':bastoni_df['d%'], 'Oggetto':bastoni_df['Bastone medio inferiore'],
     'Prezzo':bastoni_df['Fonte'], 'Fonte':bastoni_df['Unnamed: 6']}
bastoni_df = pd.DataFrame(d)
bastoni_df.head()
# Out:
#         d%                         Oggetto     Prezzo  \
# 0  01â10  Bastone del Conforto Benedetto   7.200 mo
# 1    11-20      Bastone dell'Arcano Minore   8.000 mo
# 2    21-30             Bastone dei Trucchi   8.800 mo
# 3    31-44        Bastone dell'Esploratore   9.600 mo
# 4        -   Bastone della Mostrificazione  12.000 mo
#
#                        Fonte
# 0  Guida all'Equipaggiamento
# 1  Guida all'Equipaggiamento
# 2  Guida all'Equipaggiamento
# 3  Guida all'Equipaggiamento
# 4          Guida alle Classi

# %%
# correct first entry
bastoni_df['d%'].iloc[0] = '01-10'
bastoni_df.head()
# Out:
#       d%                         Oggetto     Prezzo                      Fonte
# 0  01-10  Bastone del Conforto Benedetto   7.200 mo  Guida all'Equipaggiamento
# 1  11-20      Bastone dell'Arcano Minore   8.000 mo  Guida all'Equipaggiamento
# 2  21-30             Bastone dei Trucchi   8.800 mo  Guida all'Equipaggiamento
# 3  31-44        Bastone dell'Esploratore   9.600 mo  Guida all'Equipaggiamento
# 4      -   Bastone della Mostrificazione  12.000 mo          Guida alle Classi

# %%
# splitting
bastoni_df_list = split_frame(bastoni_df)
len(bastoni_df_list)
# Out:
# 4

# %%
# save
names = ['Bastoni_medi_inferiori', 'Bastoni_medi_superiori', 'Bastoni_maggiori_inferiori', 
         'Bastoni_maggioni_superiori']
save_data(bastoni_df_list, 'Bastoni', names)

# %% [markdown]
# # Pozioni

# %%
pozioni_df = []
for i in range(7):
    pozioni_df.append(pd.read_csv('data/Pozioni_' + str(i+1) +'.csv'))

# %%
pozioni_df[1].head()
# Out:
#       d% Pozione o olio comune Prezzo             Fonte
# 0    NaN      Benedire un'Arma  50 mo  Manuale di Gioco
# 1  05-14   Cura Ferite Leggere  50 mo  Manuale di Gioco
# 2  15-19  Contrastare Elementi  50 mo  Manuale di Gioco
# 3  20-27    Ingrandire Persone  50 mo  Manuale di Gioco
# 4  28-33               Saltare  50 mo  Manuale di Gioco

# %%
# correct first row
pozioni_df[1]['d%'].iloc[0] = '01-04'

# %%
# change object name
for df in pozioni_df:
    df.columns = ['d%', 'Oggetto', 'Prezzo', 'Fonte']

# %%
# names
names1 = ['Pozioni_comuni_lv' + str(i) for i in range(1,4)]
names2 = ['Pozioni_non_comuni_lv' + str(i) for i in range(1,4)]

# %%
# save
save_data([pozioni_df[0]], 'Pozioni', ['Pozioni_comuni_lv0'])
save_data(pozioni_df[1::2], 'Pozioni', names1)
save_data(pozioni_df[2::2], 'Pozioni', names2)

# %% [markdown]
# # Verghe

# %%
verghe_df = pd.read_csv('data/Verghe_1.csv')
verghe_meta_df = []
for i in range(2,5):
    verghe_meta_df.append(pd.read_csv('data/Verghe_' + str(i) + '.csv'))

# %% [markdown]
# ## Tabella base

# %%
verghe_df.head()
# Out:
#       d%                    Verga media inferiore                 Prezzo  \
# 0     01          Verga Metamagica Pietosa Minore  Verga media inferiore
# 1  02-34  Metamagica (liv. incantesimo +1) Minore  Verga media inferiore
# 2      -             Verga della Rifocalizzazione  Verga media inferiore
# 3  35-49                        Verga Inamovibile  Verga media inferiore
# 4  50-59                Verga della Forza Tonante  Verga media inferiore
#
#       Peso     Fonte Unnamed: 5                 Unnamed: 6
# 0  Nessuno  1.500 mo       5 kg        Guida del Giocatore
# 1  Nessuno  3.000 mo     2,5 kg                          -
# 2  Nessuno  5.000 mo     0,5 kg          Avventure Occulte
# 3  Nessuno  5.000 mo     2,5 kg           Manuale di Gioco
# 4  Nessuno  5.400 mo     2,5 kg  Guida all'Equipaggiamento

# %%
d = {'d%':verghe_df['d%'], 'Oggetto':verghe_df['Verga media inferiore'],
     'Prezzo':verghe_df['Fonte'], 'Fonte':verghe_df['Unnamed: 6']}
verghe_df = pd.DataFrame(d)
verghe_df.head()
# Out:
#       d%                                  Oggetto    Prezzo  \
# 0     01          Verga Metamagica Pietosa Minore  1.500 mo
# 1  02-34  Metamagica (liv. incantesimo +1) Minore  3.000 mo
# 2      -             Verga della Rifocalizzazione  5.000 mo
# 3  35-49                        Verga Inamovibile  5.000 mo
# 4  50-59                Verga della Forza Tonante  5.400 mo
#
#                        Fonte
# 0        Guida del Giocatore
# 1                          -
# 2          Avventure Occulte
# 3           Manuale di Gioco
# 4  Guida all'Equipaggiamento

# %%
verghe_df = split_frame(verghe_df)
len(verghe_df)
# Out:
# 4

# %%
# save
names = ['Verghe_medi_inferiori', 'Verga_medi_superiori', 'Verghe_maggiori_inferiori', 
         'Verghe_maggioni_superiori']
save_data(verghe_df, 'Verghe', names)

# %% [markdown]
# ## Tabella verghe metamagiche

# %%
# assign column name
columns = verghe_meta_df[0].iloc[0]
verghe_meta_df = [df.iloc[1:] for df in verghe_meta_df]
for df in verghe_meta_df:
    df.columns = columns

# %%
# save
names = ['Verghe_metamagiche_+' + str(i) for i in [1,2,3]]
save_data(verghe_meta_df, 'Verghe', names)
